# %% [markdown]
# ![WhatsApp%20Image%202021-11-14%20at%202.23.19%20PM.jpeg](attachment:WhatsApp%20Image%202021-11-14%20at%202.23.19%20PM.jpeg)

# %% [markdown]
# ###### First of all We have need to import all required Libarary's.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

import sklearn 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# ###### Now we have import our Happiness_Score_dataset.

# %%
df=pd.read_csv("G:\Intershop_21\DataTrained Project\Project-2\World Happiness Report Dataset.csv")

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head()     # Checking the first five rows of the data.
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()     # Checking the last five rows of the data.
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.sample(5)     # Checking the random five rows of the data.
# Out:
#           Country                           Region  Happiness Rank  \
# 125      Djibouti               Sub-Saharan Africa             126
# 32       Colombia      Latin America and Caribbean              33
# 34   Saudi Arabia  Middle East and Northern Africa              35
# 9       Australia        Australia and New Zealand              10
# 116         India                    Southern Asia             117
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 125            4.369         0.08096                   0.44025  0.59207
# 32             6.477         0.05051                   0.91861  1.24018
# 34             6.411         0.04633                   1.39541  1.08393
# 9              7.284         0.04083                   1.33358  1.30923
# 116            4.565         0.02043                   0.64499  0.38174
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# ###### Here data is having 158 rows × 12 columns.
# ###### Country, Region is categorical data, Happiness Rank is ordinal and other data are continuous in nature.
# ###### Happiness Score is dependent(target) variable and other are independent(input variable).

# %%
df=df.iloc[:,[0,1,2,4,5,6,7,8,9,10,11,3]]     # Happiness score is our target column, so we are changing its loaction to make it simple.

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual', 'Happiness Score'],
#       dtype='object')

# %%
df.isnull().sum()     # Checking null values are present in dataset or not.
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# Happiness Score                  0
# dtype: int64

# %%
sns.heatmap(df.isnull())     # Checking null values are present in dataset or not with the help of Seaborn(heatmap).
# Out:
# <AxesSubplot:>

# %%
df.info()     # Cheking the info of the all columns and aslo the overview.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Standard Error                 158 non-null    float64
#  4   Economy (GDP per Capita)       158 non-null    float64
#  5   Family                         158 non-null    float64
#  6   Health (Life Expectancy)       158 non-null    float64
#  7   Freedom                        158 non-null    float64
#  8   Trust (Government Corruption)  158 non-null    float64
#  9   Generosity                     158 non-null    float64
#  10  Dystopia Residual              158 non-null    float64
#  11  Happiness Score                158 non-null    float64
# ...

# %%
df.dtypes     # Checking the Datatypes os the columns.
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# Happiness Score                  float64
# dtype: object

# %%
df.nunique()     # Checking the all Unique values.
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# Happiness Score                  157
# dtype: int64

# %%
df.Region.unique()     # Checking the Unique valuein  Perticular Columns(like Region)
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
df.head(2)
# Out:
#        Country          Region  Happiness Rank  Standard Error  \
# 0  Switzerland  Western Europe               1         0.03411
# 1      Iceland  Western Europe               2         0.04884
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  \
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
#
#    Happiness Score
# 0            7.587
# 1            7.561

# %% [markdown]
# ###### We have use LabelEncoder to encode the Region columns

# %%
from sklearn.preprocessing import LabelEncoder
Le=LabelEncoder()
df['Region']=Le.fit_transform(df['Region'])

# %%
df.head()     # After Endoding the Region columns look-like this.
# Out:
#        Country  Region  Happiness Rank  Standard Error  \
# 0  Switzerland       9               1         0.03411
# 1      Iceland       9               2         0.04884
# 2      Denmark       9               3         0.03328
# 3       Norway       9               4         0.03880
# 4       Canada       5               5         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  \
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
# ...

# %%
df.describe()     # Checking the Statistics data over view
# Out:
#            Region  Happiness Rank  Standard Error  Economy (GDP per Capita)  \
# count  158.000000      158.000000      158.000000                158.000000
# mean     5.120253       79.493671        0.047885                  0.846137
# std      2.993321       45.754363        0.017146                  0.403121
# min      0.000000        1.000000        0.018480                  0.000000
# 25%      3.000000       40.250000        0.037268                  0.545808
# 50%      4.500000       79.500000        0.043940                  0.910245
# 75%      8.000000      118.750000        0.052300                  1.158448
# max      9.000000      158.000000        0.136930                  1.690420
#
#            Family  Health (Life Expectancy)     Freedom  \
# count  158.000000                158.000000  158.000000
# mean     0.991046                  0.630259    0.428615
# std      0.272369                  0.247078    0.150693
# min      0.000000                  0.000000    0.000000
# ...

# %% [markdown]
# ## EDA / Visualization of Data

# %% [markdown]
# ###### Here we will perform bivariate analysis using scatter plot.

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(df['Country'],df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Standard Error',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Family',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Health (Life Expectancy)',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Freedom',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Generosity',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Dystopia Residual',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Happiness Score'>

# %% [markdown]
# ###### After analyzing the scatter plot we can see some of the data is not normally distributed and it is not having linear relationship'
# ###### Now apply Multivariate analysis using pair plot.

# %%
sns.pairplot(df)

# %%
sns.boxplot(df['Region'])
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
sns.boxplot(df['Happiness Rank'])
# Out:
# <AxesSubplot:xlabel='Happiness Rank'>

# %%
sns.boxplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error'>

# %%
sns.boxplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)'>

# %%
sns.boxplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family'>

# %%
sns.boxplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)'>

# %%
sns.boxplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom'>

# %%
sns.boxplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)'>

# %%
sns.boxplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity'>

# %%
sns.boxplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual'>

# %%
sns.boxplot(df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Happiness Score'>

# %% [markdown]
# ###### After ploying the box polt we observed our data is having outliers

# %%
sns.distplot(df['Region'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Density'>

# %%
sns.distplot(df['Happiness Rank'])
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %%
sns.distplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %%
sns.distplot(df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %% [markdown]
# ###### After ploying the dist polt we observed our data is having outliers

# %% [markdown]
# ###### After Checking the all graph we observed that some outliers and skwness present in some columns

# %%
df.skew()
# Out:
# Region                          -0.116119
# Happiness Rank                   0.000418
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# Happiness Score                  0.097769
# dtype: float64

# %% [markdown]
# ###### Here we can see skewness is present inside our dataset. Standard Error ,Trust (Government Corruption), Generosity,Health (Life Expectancy) having more skewness.

# %%
df= df.drop(['Country','Happiness Rank'], axis=1)

# %% [markdown]
# ###### Here we are deleting Country, Happiness Rank columns as it is not having any effect target.

# %%
df
# Out:
#      Region  Standard Error  Economy (GDP per Capita)   Family  \
# 0         9         0.03411                   1.39651  1.34951
# 1         9         0.04884                   1.30232  1.40223
# 2         9         0.03328                   1.32548  1.36058
# 3         9         0.03880                   1.45900  1.33095
# 4         5         0.03553                   1.32629  1.32261
# ..      ...             ...                       ...      ...
# 153       8         0.03464                   0.22208  0.77370
# 154       8         0.03656                   0.28665  0.35386
# 155       4         0.05015                   0.66320  0.47489
# 156       8         0.08658                   0.01530  0.41587
# 157       8         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Region                         158 non-null    int32
#  1   Standard Error                 158 non-null    float64
#  2   Economy (GDP per Capita)       158 non-null    float64
#  3   Family                         158 non-null    float64
#  4   Health (Life Expectancy)       158 non-null    float64
#  5   Freedom                        158 non-null    float64
#  6   Trust (Government Corruption)  158 non-null    float64
#  7   Generosity                     158 non-null    float64
#  8   Dystopia Residual              158 non-null    float64
#  9   Happiness Score                158 non-null    float64
# dtypes: float64(9), int32(1)
# memory usage: 11.9 KB

# %%
df.describe()
# Out:
#            Region  Standard Error  Economy (GDP per Capita)      Family  \
# count  158.000000      158.000000                158.000000  158.000000
# mean     5.120253        0.047885                  0.846137    0.991046
# std      2.993321        0.017146                  0.403121    0.272369
# min      0.000000        0.018480                  0.000000    0.000000
# 25%      3.000000        0.037268                  0.545808    0.856823
# 50%      4.500000        0.043940                  0.910245    1.029510
# 75%      8.000000        0.052300                  1.158448    1.214405
# max      9.000000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# std                    0.247078    0.150693                       0.120034
# ...

# %%
df.corr()
# Out:
#                                  Region  Standard Error  \
# Region                         1.000000       -0.022600
# Standard Error                -0.022600        1.000000
# Economy (GDP per Capita)      -0.260139       -0.217651
# Family                        -0.168533       -0.120728
# Health (Life Expectancy)      -0.357508       -0.310287
# Freedom                        0.092567       -0.129773
# Trust (Government Corruption)  0.165040       -0.178325
# Generosity                     0.273557       -0.088439
# Dystopia Residual             -0.057276        0.083981
# Happiness Score               -0.176791       -0.177254
#
#                                Economy (GDP per Capita)    Family  \
# Region                                        -0.260139 -0.168533
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# ...

# %%
plt.figure(figsize=(16,7))
sns.heatmap(df.corr(), annot=True, linewidths=2,linecolor='black',fmt=' .2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### Here Region , Standard error are having very less relationship with target.
# ###### Economy (GDP per Capita),Health (Life Expectancy),Family, Trust (Government Corruption), Dystopia Residual Happiness Having strog relationship.

# %% [markdown]
# #### Removing Outliers

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
# array([[1.30025593, 0.80592569, 1.36962124, ..., 0.47103971, 0.75825809,
#         1.93736005],
#        [1.30025593, 0.05588945, 1.13522625, ..., 1.57585637, 1.09285682,
#         1.91458063],
#        [1.30025593, 0.8544869 , 1.19286069, ..., 0.8242928 , 0.71233526,
#         1.88479215],
#        ...,
#        [0.37544095, 0.13253425, 0.45524543, ..., 1.85689094, 3.20843049,
#         2.0761992 ],
#        [0.96511655, 2.26396166, 2.06756644, ..., 0.31694987, 0.48198451,
#         2.1646885 ],
#        [0.96511655, 1.13418227, 1.58633379, ..., 0.5581534 , 0.96361241,
#         2.22251319]])

# %%
z.shape
# Out:
# (158, 10)

# %%
threshold= 3 
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([6, 1, 1, 1, 7, 3, 6, 8, 3], dtype=int64))

# %%
df_new = df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (158, 10)
# (149, 10)

# %%
Loss_percentage=(158-149)/158*100
print(Loss_percentage)
# Out:
# 5.69620253164557

# %% [markdown]
# ######  Now split data in dependent and indipendent variable

# %%
df.head()
# Out:
#    Region  Standard Error  Economy (GDP per Capita)   Family  \
# 0       9         0.03411                   1.39651  1.34951
# 1       9         0.04884                   1.30232  1.40223
# 2       9         0.03328                   1.32548  1.36058
# 3       9         0.03880                   1.45900  1.33095
# 4       5         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual  Happiness Score
# 0     0.29678            2.51738            7.587
# 1     0.43630            2.70201            7.561
# ...

# %%
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

# %% [markdown]
# ###### Dependent variable in stored in y and indipendent variables are saved in x

# %%
x.shape
# Out:
# (158, 9)

# %%
y.shape
# Out:
# (158,)

# %%
from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 1.24453048, -0.9722262 ,  1.44606101, ...,  1.77399061,
#          0.62239051,  0.75099154],
#        [ 1.24453048,  0.30934969,  1.17332111, ...,  0.31599326,
#          1.48099498,  1.11001108],
#        [ 1.24453048, -1.06201662,  1.23983557, ...,  1.90679207,
#          0.92797276,  0.70227525],
#        ...,
#        [-0.30300992,  0.39913742, -0.5134688 , ...,  0.73891461,
#          1.65933595, -2.86621557],
#        [ 0.95510156,  1.92690194, -1.89495386, ..., -0.15194624,
#         -0.19482942, -0.51480136],
#        [ 0.95510156,  1.31032295, -1.52122584, ..., -0.06732623,
#         -0.49041465, -0.97664547]])

# %%
from sklearn.preprocessing import StandardScaler

# %%
sd=StandardScaler()
xsd=sd.fit_transform(x)

# %%
x=pd.DataFrame(xsd)

# %%
x
# Out:
#             0         1         2         3         4         5         6  \
# 0    1.244530 -0.972226  1.446061  1.669206  1.491765  1.756335  1.773991
# 1    1.244530  0.309350  1.173321  2.012132  1.532348  1.439946  0.315993
# 2    1.244530 -1.062017  1.239836  1.739586  1.085223  1.615733  1.906792
# 3    1.244530 -0.503610  1.630246  1.553118  1.147600  1.792821  1.624007
# 4    0.030337 -0.823548  1.242168  1.501726  1.270179  1.475479  1.503484
# ..        ...       ...       ...       ...       ...       ...       ...
# 153  0.955102 -0.916014 -1.494046 -0.959885 -0.939459  1.135229  2.012856
# 154  0.955102 -0.719479 -1.360829 -1.896644 -1.276496  0.307514 -0.433835
# 155 -0.303010  0.399137 -0.513469 -1.690664  0.262933 -1.668658  0.738915
# 156  0.955102  1.926902 -1.894954 -1.796803 -1.525700 -1.849903 -0.151946
# 157  0.955102  1.310323 -1.521226 -2.160397 -1.371811 -0.508362 -0.067326
#
#             7         8
# 0    0.622391  0.750992
# 1    1.480995  1.110011
# ...

# %% [markdown]
# ###### Importing methods to perform taring and testing of the data.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
lm=LinearRegression()
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %% [markdown]
# ###### Splitting the DataFrame

# %%
for i in range(0, 500):
    x_train, x_test, y_train, y_test= train_test_split(x,y,random_state= i,test_size=0.20)
    lm.fit(x_train,y_train)
    pred_train= lm.predict(x_train)
    pred_test= lm.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,1)==round(r2_score(y_test,pred_test)*100,1):
        print("At Random state",i, "The model perform very well")
        print("At random State:",i)
        print("Training r2_score",r2_score(y_train,pred_train)*100)
        print("testing r2 score ",r2_score(y_test,pred_test)*100)
# Out:
# At Random state 0 The model perform very well
# At random State: 0
# Training r2_score 99.2885897613442
# testing r2 score  99.30725099239369
# At Random state 1 The model perform very well
# At random State: 1
# Training r2_score 99.28498773138148
# testing r2 score  99.28058256724391
# At Random state 6 The model perform very well
# At random State: 6
# Training r2_score 99.26762862759715
# testing r2 score  99.33308807223423
# At Random state 11 The model perform very well
# At random State: 11
# Training r2_score 99.27912034731375
# testing r2 score  99.31494773857247
# At Random state 68 The model perform very well
# At random State: 68
# Training r2_score 99.28681454938278
# testing r2 score  99.31069133082046
# At Random state 69 The model perform very well
# At random State: 69
# Training r2_score 99.28532571955976
# testing r2 score  99.26434382723819
# At Random state 89 The model perform very well
# At random State: 89
# Training r2_score 99.26500882661162
# ...

# %% [markdown]
# ###### Here we observed best random state is 182 giving high value of r2 score

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.25,random_state=182)

# %%
models=[KNeighborsRegressor(),SVR(),DecisionTreeRegressor(),LinearRegression(),Ridge(),Lasso(),RandomForestRegressor(),AdaBoostRegressor(),GradientBoostingRegressor()]

# %%
maelist=[]
mselist=[]
rmselist=[]
r2list=[]
def create_model(model):
    m=model
    m.fit(x_train,y_train)
    p=m.predict(x_test)
    
    mae=mean_absolute_error(p,y_test)
    mse=mean_squared_error(p,y_test)
    rmse=np.sqrt(mean_squared_error(p,y_test))
    r2=r2_score(y_test,p)
    
    maelist.append(mae)
    mselist.append(mse)
    rmselist.append(rmse)
    r2list.append(r2)
    print(m)
    print('Mean absolute error',mae)
    print('Mean squared error',mse)
    print('Root Mean squared error',rmse)
    print('R2 Score',r2)
    print('========================================================================================================')

# %% [markdown]
# ###### Here we are training and testing our data with multiple model to find out the best suitable model.

# %%
for i in models:
    create_model(i)
# Out:
# KNeighborsRegressor()
# Mean absolute error 0.4035350000000001
# Mean squared error 0.2396275570000001
# Root Mean squared error 0.48951767792389284
# R2 Score 0.7856914565322831
# ...
# SVR()
# Mean absolute error 0.22820394726709187
# Mean squared error 0.1605529718844053
# Root Mean squared error 0.4006906186628348
# R2 Score 0.856411032250518
# ...
# DecisionTreeRegressor()
# Mean absolute error 0.535625
# Mean squared error 0.5274110249999999
# Root Mean squared error 0.7262306968174782
# R2 Score 0.5283151487599336
# ...
# LinearRegression()
# Mean absolute error 0.06572059888338336
# Mean squared error 0.00715797280266144
# Root Mean squared error 0.08460480366185741
# R2 Score 0.9935983375838535
# ...
# Ridge()
# Mean absolute error 0.0664250453645434
# Mean squared error 0.007442451002108932
# Root Mean squared error 0.08626964125408736
# R2 Score 0.9933439173104293
# ...
# Lasso()
# Mean absolute error 0.8878677966101695
# Mean squared error 1.1187214978741742
# ...

# %%
print('Minimum Mean Absolute error is shown by ',models[maelist.index(min(maelist))],min(maelist))
print('Minimum Mean squared error is shown by ',models[mselist.index(min(mselist))],min(mselist))
print('Minimum Root Mean squared error is shown by ',models[rmselist.index(min(rmselist))],min(rmselist))
print('Maximun R2 Score is shown by ',models[r2list.index(max(r2list))],max(r2list))
# Out:
# Minimum Mean Absolute error is shown by  LinearRegression() 0.06572059888338336
# Minimum Mean squared error is shown by  LinearRegression() 0.00715797280266144
# Minimum Root Mean squared error is shown by  LinearRegression() 0.08460480366185741
# Maximun R2 Score is shown by  LinearRegression() 0.9935983375838535

# %% [markdown]
# ###### Saving the best model

# %%
lrm=LinearRegression()
lrm.fit(x,y)
# Out:
# LinearRegression()

# %%
import pickle
filename='World_Happiness_Report.pkl'
pickle.dump(lrm,open(filename,'wb'))

# %% [markdown]
# # Conclusion¶

# %%
 import numpy as np
a=np.array(y_test)
predicted= np.array(lrm.predict(x_test))
df_com= pd.DataFrame({'original':a, 'predicted':predicted}, index= range(len(a)))
df_com
# Out:
#     original  predicted
# 0      5.878   5.904081
# 1      4.874   4.946368
# 2      4.610   4.562747
# 3      5.833   5.820609
# 4      4.800   4.879195
# 5      7.226   7.334715
# 6      6.983   7.028110
# 7      5.984   6.048832
# 8      5.268   5.236130
# 9      4.194   4.166128
# 10     4.297   4.281882
# 11     4.571   4.539599
# 12     6.302   6.324462
# 13     6.411   6.335733
# 14     3.904   3.857586
# 15     5.709   5.620158
# 16     5.007   4.984394
# 17     4.681   4.709517
# 18     7.187   7.205373
# 19     4.077   4.023144
# 20     3.006   3.278515
# 21     4.514   4.393541
# 22     3.819   3.862542
# 23     6.940   6.990292
# 24     5.754   5.714499
# 25     5.605   5.506330
# 26     6.168   6.114798
# 27     5.824   5.738968
# 28     5.477   5.346625
# 29     6.575   6.623446
# 30     3.465   3.339625
# 31     5.589   5.544768
# 32     5.548   5.529269
# 33     5.192   5.187918
# 34     6.853   6.801218
# 35     6.485   6.500844
# 36     4.517   4.647384
# ...
