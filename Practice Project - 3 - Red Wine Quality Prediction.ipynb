# %% [markdown]
# ![shutterstock_647463025-2.jpg](attachment:shutterstock_647463025-2.jpg)

# %% [markdown]
# ###### First of all We have need to import all required Libarary's.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ###### Now we have import our Red_Winequality_dataset.

# %%
df=pd.read_csv("G:\Intershop_21\DataTrained Project\Project - 3 - Red Wine\winequality-red.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.head()     # Checking the first five rows of the data.
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.tail()     # Checking the last five rows of the data.
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6

# %%
df.sample(5)     # Checking the random five rows of the data.
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 242             7.7              0.58         0.10             1.8      0.102
# 1320            9.7              0.66         0.34             2.6      0.094
# 1378            7.2              0.45         0.15             2.0      0.078
# 1402            7.6              0.30         0.42             2.0      0.052
# 926             9.4              0.24         0.33             2.3      0.061
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 242                  28.0                 109.0  0.99565  3.08       0.49
# 1320                 12.0                  88.0  0.99796  3.26       0.66
# 1378                 10.0                  28.0  0.99609  3.29       0.51
# 1402                  6.0                  24.0  0.99630  3.44       0.82
# 926                  52.0                  73.0  0.99786  3.47       0.90
#
#       alcohol  quality
# 242       9.8        6
# 1320     10.1        5
# 1378      9.9        6
# 1402     11.9        6
# 926      10.2        6

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.isnull().sum()     # Checking null values are present in dataset or not.
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
sns.heatmap(df.isnull())     # Checking null values are present in dataset or not with the help of Seaborn(heatmap).
# Out:
# <AxesSubplot:>

# %%
df.info()     # Cheking the info of the all columns and aslo the overview.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.dtypes     # Checking the Datatypes os the columns.
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
sns.countplot(df['quality'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
df.nunique()
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %% [markdown]
# ## EDA / Visualization of Data

# %% [markdown]
# ###### Here we will perform bivariate analysis

# %%
df.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5

# %%
sns.scatterplot(data=df, x="fixed acidity", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %%
sns.scatterplot(data=df, x="volatile acidity", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='quality'>

# %%
sns.scatterplot(data=df, x="citric acid", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='quality'>

# %%
sns.scatterplot(data=df, x="residual sugar", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='quality'>

# %%
sns.scatterplot(data=df, x="chlorides", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='quality'>

# %%
sns.scatterplot(data=df, x="free sulfur dioxide", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(data=df, x="total sulfur dioxide", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(data=df, x="density", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='density', ylabel='quality'>

# %%
sns.scatterplot(data=df, x="pH", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %%
sns.scatterplot(data=df, x="sulphates", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='quality'>

# %%
sns.scatterplot(data=df, x="alcohol", y="quality", hue="quality")
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %%
X= df.drop(columns=['quality'])
Y=df['quality']

# %%
plt.figure(figsize=(20,20), facecolor='orange')
plotnumber= 1

for column in X:
    if plotnumber<=14:
        ax= plt.subplot(4,3, plotnumber)
        sns.scatterplot(X[column], Y, hue=Y)
        plt.xlabel(column, fontsize= 20)
        plt.ylabel('quality', fontsize= 20)
    plotnumber+=1
plt.tight_layout()

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
sns.distplot(df['fixed acidity'])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %% [markdown]
# The Data is not normalised. The building blocks are out of normalised curve.

# %%
sns.distplot(df['volatile acidity'])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %% [markdown]
# The Data is not normalised. The building blocks are out of normalised curve.

# %%
sns.distplot(df['citric acid'])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %% [markdown]
# The Data is not normalised. The building blocks are out of normalised curve.

# %%
sns.distplot(df['residual sugar'])
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Density'>

# %% [markdown]
# The Data is not normalised. The building blocks are out of normalised curve.

# %%
sns.distplot(df['chlorides'])
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %% [markdown]
# The Data is not normalised. The building blocks are out of normalised curve.

# %%
sns.distplot(df['free sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %% [markdown]
# The Data is not normalised. The building blocks are out of normalised curve.

# %%
sns.distplot(df['total sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='Density'>

# %% [markdown]
# The Data is not normalised. The building blocks are out of normalised curve.

# %%
sns.distplot(df['density'])
# Out:
# <AxesSubplot:xlabel='density', ylabel='Density'>

# %% [markdown]
# The Data is not normalised. The building blocks are out of normalised curve.

# %%
sns.distplot(df['pH'])
# Out:
# <AxesSubplot:xlabel='pH', ylabel='Density'>

# %% [markdown]
# The Data is not normalised. The building blocks are out of normalised curve.

# %%
sns.distplot(df['sulphates'])
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='Density'>

# %% [markdown]
# The Data is not normalised. The building blocks are out of normalised curve.

# %%
sns.distplot(df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# The Data is not normalised. The building blocks are out of normalised curve.

# %%
plt.figure(figsize=(20,20), facecolor='orange')
plotnumber= 1

for column in X:
    if plotnumber<=14:
        ax= plt.subplot(4,3, plotnumber)
        sns.distplot(X[column])
        plt.xlabel(column, fontsize= 20)
        plt.ylabel('quality', fontsize= 20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # The Normal distribution shows that the data is skewed.

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %% [markdown]
# As we can see alchol,sulphates, citric acid etc seem to play a lot of role in determining quality

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True,linewidths=1,linecolor='black',fmt=' .2f')
# Out:
# <AxesSubplot:>

# %%
collist=df.columns.values
ncol= 10
nrows= 10

plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows, ncol, i+1)
    sns.boxplot(y=df[collist[i]], color='green', orient='x')
    plt.tight_layout()

# %% [markdown]
# We can see Data is having Outliers.

# %% [markdown]
# # Removing outliers

# %%
from scipy.stats import zscore

# %%
z= np.abs (zscore(df))
threshold=3 
np.where(z>3)
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#           45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#          106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#          151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#          244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#          354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#          459,  467,  480,  480,  494,  515,  517,  544,  554,  554,  555,
#          555,  557,  557,  568,  584,  588,  591,  595,  608,  614,  636,
#          639,  649,  649,  651,  652,  652,  652,  672,  672,  684,  690,
#          690,  692,  692,  695,  723,  724,  730,  754,  776,  777,  795,
#          821,  832,  836,  837,  889,  899,  911,  917,  923,  925,  926,
#          982, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1079, 1081,
#         1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186, 1231, 1235, 1244,
#         1244, 1244, 1260, 1269, 1269, 1270, 1270, 1288, 1289, 1295, 1296,
#         1299, 1299, 1300, 1312, 1316, 1319, 1319, 1321, 1358, 1367, 1370,
#         1370, 1372, 1372, 1374, 1374, 1434, 1434, 1434, 1435, 1435, 1435,
#         1469, 1474, 1474, 1474, 1476, 1476, 1476, 1478, 1493, 1496, 1505,
#         1558, 1558, 1570, 1574, 1589], dtype=int64),
#  array([ 9,  5,  5,  6,  4,  9,  4,  3,  1,  4,  9,  8,  5,  4,  9,  4,  9,
#          9,  9,  9,  8,  4,  9,  6,  1,  1,  1, 10, 10,  4,  2,  4,  8,  9,
#          3,  3,  4,  9,  4,  1,  4,  9,  4,  0,  0,  4,  9,  3,  4,  4,  3,
#          3,  9,  9,  0,  6,  0,  0,  0,  3,  5,  3,  5,  0,  7,  4, 11, 10,
#          3,  7,  3,  6, 11,  0,  0,  7,  0,  7,  0,  7,  4,  5, 10,  6,  3,
#          7,  9,  6,  9,  3,  6,  6,  0,  3, 10,  1,  6,  6,  1, 11,  4,  9,
#          8,  9,  1,  4,  4,  4,  4,  9, 10, 11,  7,  7,  7, 11,  3,  3,  3,
#          5,  5,  5,  7,  7,  3,  4,  9,  3,  3,  3,  6,  3,  6,  8,  7,  5,
#          5,  4,  5,  3,  5,  3,  3,  5,  6,  4,  7, 10,  7, 10,  9,  9,  5,
#          5,  1, 11,  8,  1,  8,  4,  9,  8,  5,  9,  4,  9,  4,  9,  4, 11,
#          3,  5,  7,  3,  5,  7, 11,  3,  5,  7,  3,  5,  7, 11,  6,  6, 11,
#          4,  5,  4,  3,  3], dtype=int64))

# %%
z.shape
# Out:
# (1599, 12)

# %%
df_new = df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (1599, 12)
# (1451, 12)

# %%
Loss_percentage=(1599-1451)/1599*100
print(Loss_percentage)
# Out:
# 9.255784865540964

# %%
wine_quality=[]
for i in df_new["quality"]:
    if i >=7:
        wine_quality.append(1)
    else:
        wine_quality.append(0)
df_new["wine_cat"]=wine_quality

# %% [markdown]
# dependent variable (wine quality) at e.g. 7 or higher getting classified as '1' and the remainder as '0'.

# %% [markdown]
# # Removing Skweness

# %%
from sklearn.preprocessing import power_transform

# %% [markdown]
# Dividing data in feature and vectors.

# %%
x=df_new.iloc[:,0:-2]

# %%
y=df_new.iloc[:,-1]

# %%
x.shape
# Out:
# (1451, 11)

# %%
y.shape
# Out:
# (1451,)

# %%
x=power_transform(x,method='yeo-johnson')

# %%
x.shape
# Out:
# (1451, 11)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.46787818,  1.05573967, -1.52450588, ...,  1.36086042,
#         -0.58965734, -1.12042399],
#        [-0.17080535,  1.91974976, -1.52450588, ..., -0.81650738,
#          0.45152416, -0.5303401 ],
#        [-0.17080535,  1.35706712, -1.24543379, ..., -0.38097654,
#          0.22000451, -0.5303401 ],
#        ...,
#        [-1.45100718, -0.00286664, -0.66625579, ...,  0.74685493,
#          0.93043194,  0.74288203],
#        [-1.88546393,  0.76651828, -0.72755539, ...,  1.76243705,
#          0.666655  , -0.03416625],
#        [-1.7722373 , -1.33320495,  1.07130142, ...,  0.53899166,
#          0.29909273,  0.74288203]])

# %% [markdown]
# Scaling tha data using StandardScaler for good model training.

# %%
sns.countplot(df_new['wine_cat'])
# Out:
# <AxesSubplot:xlabel='wine_cat', ylabel='count'>

# %%
df_new['wine_cat'].value_counts()
# Out:
# 0    1250
# 1     201
# Name: wine_cat, dtype: int64

# %% [markdown]
# Here we can see our output is not balanced we will now use SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
X_train_over, y_train_over = SMOTE(k_neighbors=3).fit_resample(x,y)

# %%
X_train_over
# Out:
# array([[-0.46787818,  1.05573967, -1.52450588, ...,  1.36086042,
#         -0.58965734, -1.12042399],
#        [-0.17080535,  1.91974976, -1.52450588, ..., -0.81650738,
#          0.45152416, -0.5303401 ],
#        [-0.17080535,  1.35706712, -1.24543379, ..., -0.38097654,
#          0.22000451, -0.5303401 ],
#        ...,
#        [ 1.26560264, -0.64363179,  1.19650051, ..., -1.46087767,
#          0.23840011,  1.31135777],
#        [ 0.40877426, -0.98199031,  0.58700435, ..., -0.05071625,
#          0.71413285,  1.32044723],
#        [-2.92360612,  0.14789153, -0.76705111, ...,  1.25339097,
#          1.69667245,  1.86642953]])

# %%
y_train_over.value_counts()
# Out:
# 0    1250
# 1    1250
# Name: wine_cat, dtype: int64

# %%
sns.countplot(y_train_over)
# Out:
# <AxesSubplot:xlabel='wine_cat', ylabel='count'>

# %% [markdown]
# Now our data is balanced. we can proceed further.

# %%
xtrain=pd.DataFrame(data=X_train_over, columns=df.columns[0:11])
xtrain
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.467878          1.055740    -1.524506       -0.610683  -0.145035
# 1         -0.170805          1.919750    -1.524506        0.649155   0.986838
# 2         -0.170805          1.357067    -1.245434        0.207601   0.718578
# 3          1.573404         -1.556675     1.444056       -0.610683  -0.207213
# 4         -0.467878          1.055740    -1.524506       -0.610683  -0.145035
# ...             ...               ...          ...             ...        ...
# 2495       0.958921          0.739848     0.658526        1.090382   0.321956
# 2496      -0.864223          0.309639    -0.697298        0.320605  -0.944223
# 2497       1.265603         -0.643632     1.196501       -0.038386   1.255635
# 2498       0.408774         -0.981990     0.587004        1.247398  -0.996454
# 2499      -2.923606          0.147892    -0.767051       -0.506427  -2.921790
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0               -0.241492             -0.066536  0.640791  1.360860
# 1                1.091561              0.952517  0.061011 -0.816507
# 2                0.238587              0.624244  0.177435 -0.380977
# 3                0.440493              0.784119  0.756049 -1.110847
# 4               -0.241492             -0.066536  0.640791  1.360860
# ...                   ...                   ...       ...       ...
# 2495             0.965976              0.795958  1.083210  0.276697
# 2496             0.494396             -0.107717 -1.576380  0.827982
# 2497            -1.093058             -1.656342  0.057004 -1.460878
# 2498            -0.383120             -0.791685 -0.978723 -0.050716
# 2499             0.268939              1.501070 -2.510352  1.253391
#
#       sulphates   alcohol
# 0     -0.589657 -1.120424
# 1      0.451524 -0.530340
# 2      0.220005 -0.530340
# 3     -0.393177 -0.530340
# 4     -0.589657 -1.120424
# ...         ...       ...
# 2495   0.692692  1.155246
# 2496   0.235270  1.406215
# 2497   0.238400  1.311358
# 2498   0.714133  1.320447
# 2499   1.696672  1.866430
#
# [2500 rows x 11 columns]

# %%
ytrain=pd.DataFrame(data=y_train_over)
ytrain
# Out:
#       wine_cat
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 2495         1
# 2496         1
# 2497         1
# 2498         1
# 2499         1
#
# [2500 rows x 1 columns]

# %%
import statsmodels.api as sm
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc_vif(xtrain):
    vif=pd.DataFrame()
    vif['variables']=xtrain.columns
    vif['VIF FACTOR']=[variance_inflation_factor(xtrain.values,i) for i in range(xtrain.shape[1])]
    return(vif)

# %%
calc_vif(xtrain)
# Out:
#                variables  VIF FACTOR
# 0          fixed acidity    8.293762
# 1       volatile acidity    2.543058
# 2            citric acid    4.142406
# 3         residual sugar    1.804588
# 4              chlorides    1.458491
# 5    free sulfur dioxide    2.998343
# 6   total sulfur dioxide    3.622383
# 7                density    6.704933
# 8                     pH    3.455395
# 9              sulphates    1.718893
# 10               alcohol    4.170602

# %% [markdown]
# As we can see VIF is less than 10 we will not remove any columns, and proceed further.
#
# Since our output is having only two values "0" and "1", we will use binary classification model.

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix 

lr=LogisticRegression()

# %%
for i in range(0,1000):
    x_train, x_test, y_train, y_test = train_test_split(xtrain,ytrain,random_state= i, test_size=.20)
    lr.fit(x_train,y_train)
    pred_train= lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train, pred_train)*100,1)== round(accuracy_score(y_test, pred_test)*100,1):
        print("At Random state",i, "The model perform very well")
        print("At random State:",i)
        print("Training r2_score",accuracy_score(y_train,pred_train)*100)
        print("testing r2 score ",accuracy_score(y_test,pred_test)*100)
# Out:
# At Random state 54 The model perform very well
# At random State: 54
# Training r2_score 81.8
# testing r2 score  81.8
# At Random state 63 The model perform very well
# At random State: 63
# Training r2_score 81.8
# testing r2 score  81.8
# At Random state 75 The model perform very well
# At random State: 75
# Training r2_score 81.95
# testing r2 score  82.0
# At Random state 143 The model perform very well
# At random State: 143
# Training r2_score 81.55
# testing r2 score  81.6
# At Random state 192 The model perform very well
# At random State: 192
# Training r2_score 82.35
# testing r2 score  82.39999999999999
# At Random state 260 The model perform very well
# At random State: 260
# Training r2_score 82.05
# testing r2 score  82.0
# At Random state 276 The model perform very well
# At random State: 276
# Training r2_score 81.8
# testing r2 score  81.8
# At Random state 284 The model perform very well
# At random State: 284
# Training r2_score 82.45
# testing r2 score  82.39999999999999
# At Random state 285 The model perform very well
# At random State: 285
# Training r2_score 81.65
# testing r2 score  81.6
# At Random state 289 The model perform very well
# At random State: 289
# Training r2_score 81.85
# testing r2 score  81.8
# At Random state 398 The model perform very well
# At random State: 398
# Training r2_score 82.0
# testing r2 score  82.0
# At Random state 463 The model perform very well
# At random State: 463
# Training r2_score 81.95
# testing r2 score  82.0
# At Random state 479 The model perform very well
# At random State: 479
# Training r2_score 82.35
# testing r2 score  82.39999999999999
# At Random state 533 The model perform very well
# At random State: 533
# Training r2_score 81.95
# testing r2 score  82.0
# At Random state 576 The model perform very well
# At random State: 576
# Training r2_score 82.05
# testing r2 score  82.0
# At Random state 601 The model perform very well
# At random State: 601
# Training r2_score 82.25
# testing r2 score  82.19999999999999
# At Random state 720 The model perform very well
# At random State: 720
# Training r2_score 82.15
# testing r2 score  82.19999999999999
# At Random state 723 The model perform very well
# At random State: 723
# Training r2_score 82.25
# testing r2 score  82.19999999999999
# At Random state 766 The model perform very well
# At random State: 766
# Training r2_score 82.15
# testing r2 score  82.19999999999999
# At Random state 786 The model perform very well
# At random State: 786
# Training r2_score 81.85
# testing r2 score  81.8
# At Random state 803 The model perform very well
# At random State: 803
# Training r2_score 82.55
# testing r2 score  82.6
# At Random state 808 The model perform very well
# At random State: 808
# Training r2_score 82.05
# testing r2 score  82.0
# At Random state 816 The model perform very well
# At random State: 816
# Training r2_score 82.19999999999999
# testing r2 score  82.19999999999999
# At Random state 819 The model perform very well
# At random State: 819
# Training r2_score 81.65
# testing r2 score  81.6
# At Random state 825 The model perform very well
# At random State: 825
# Training r2_score 82.05
# testing r2 score  82.0
# At Random state 839 The model perform very well
# At random State: 839
# Training r2_score 82.45
# testing r2 score  82.39999999999999
# At Random state 875 The model perform very well
# At random State: 875
# Training r2_score 82.39999999999999
# testing r2 score  82.39999999999999
# At Random state 959 The model perform very well
# At random State: 959
# Training r2_score 81.8
# testing r2 score  81.8

# %%
x_train, x_test, y_train, y_test= train_test_split(xtrain,ytrain,random_state=940,test_size=0.20)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.43      0.46       242
#            1       0.52      0.58      0.55       258
#
#     accuracy                           0.51       500
#    macro avg       0.51      0.51      0.51       500
# weighted avg       0.51      0.51      0.51       500

# %%
pred_lr = lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(y_test,pred_lr)
for j in range(2,10):
    lsscore= cross_val_score(lr,xtrain,ytrain,cv=j)
    lsc=lsscore.mean()
    print("at cv:-", j)
    print("Cross Validation scre is:-",lsc*100)
    print("Accuracy Score:-", lss*100)
    print("\n")
# Out:
# at cv:- 2
# Cross Validation scre is:- 78.0
# Accuracy Score:- 84.8
#
#
# at cv:- 3
# Cross Validation scre is:- 79.47884189647083
# Accuracy Score:- 84.8
#
#
# at cv:- 4
# Cross Validation scre is:- 80.64
# Accuracy Score:- 84.8
#
#
# at cv:- 5
# Cross Validation scre is:- 80.28
# Accuracy Score:- 84.8
#
#
# at cv:- 6
# Cross Validation scre is:- 80.31670817192399
# Accuracy Score:- 84.8
#
#
# at cv:- 7
# Cross Validation scre is:- 80.91627712537529
# Accuracy Score:- 84.8
#
#
# at cv:- 8
# Cross Validation scre is:- 80.83271893176047
# Accuracy Score:- 84.8
#
#
# at cv:- 9
# Cross Validation scre is:- 81.23912422408644
# Accuracy Score:- 84.8

# %%
lssscore_selected=cross_val_score(lr,xtrain,ytrain,cv=9).mean()
print("The cv score is: ", lssscore_selected,"\nThe accuracy score is: ", lss)
# Out:
# The cv score is:  0.8123912422408643
# The accuracy score is:  0.848

# %%
rfcv=RandomForestClassifier()
rfcv.fit(x_train, y_train)
rfcv.score(x_train,y_train)
rfpred=rfcv.predict(x_test)

print (accuracy_score(y_test,rfpred))
print (confusion_matrix(y_test,rfpred))
print (classification_report(y_test,rfpred))
print('\n')
# Out:
# 0.946
# [[229  13]
#  [ 14 244]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94       242
#            1       0.95      0.95      0.95       258
#
#     accuracy                           0.95       500
#    macro avg       0.95      0.95      0.95       500
# weighted avg       0.95      0.95      0.95       500

# %%
RFA=accuracy_score(y_test,rfpred)
RFcv=cross_val_score(rfcv,xtrain,ytrain,cv=9).mean()
print("The cv score is: ", RFcv,"\nThe accuracy score is: ", RFA)
# Out:
# The cv score is:  0.9387984197479562
# The accuracy score is:  0.946

# %%
gbcv=GaussianNB()
gbcv.fit(x_train, y_train)
gbcv.score(x_train,y_train)
gbpred=gbcv.predict(x_test)

print (accuracy_score(y_test,gbpred))
print (confusion_matrix(y_test,gbpred))
print (classification_report(y_test,gbpred))
print('\n')
# Out:
# 0.828
# [[196  46]
#  [ 40 218]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82       242
#            1       0.83      0.84      0.84       258
#
#     accuracy                           0.83       500
#    macro avg       0.83      0.83      0.83       500
# weighted avg       0.83      0.83      0.83       500

# %%
GBA=accuracy_score(y_test,rfpred)
GBcv=cross_val_score(gbcv,xtrain,ytrain,cv=9).mean()
print("The cv score is: ", GBcv,"\nThe accuracy score is: ", GBA)
# Out:
# The cv score is:  0.7964083606760801
# The accuracy score is:  0.946

# %%
kccv=KNeighborsClassifier()
kccv.fit(x_train, y_train)
kccv.score(x_train,y_train)
kcpred=kccv.predict(x_test)

print (accuracy_score(y_test,kcpred))
print (confusion_matrix(y_test,kcpred))
print (classification_report(y_test,kcpred))
print('\n')
# Out:
# 0.878
# [[188  54]
#  [  7 251]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.78      0.86       242
#            1       0.82      0.97      0.89       258
#
#     accuracy                           0.88       500
#    macro avg       0.89      0.87      0.88       500
# weighted avg       0.89      0.88      0.88       500

# %%
KCA=accuracy_score(y_test,kcpred)
KCcv=cross_val_score(kccv,xtrain,ytrain,cv=9).mean()
print("The cv score is: ", KCcv,"\nThe accuracy score is: ", KCA)
# Out:
# The cv score is:  0.8599733931266539
# The accuracy score is:  0.878

# %%
dtcv=DecisionTreeClassifier()
dtcv.fit(x_train, y_train)
dtcv.score(x_train,y_train)
dtpred=dtcv.predict(x_test)

print (accuracy_score(y_test,dtpred))
print (confusion_matrix(y_test,dtpred))
print (classification_report(y_test,dtpred))
print('\n')
# Out:
# 0.898
# [[212  30]
#  [ 21 237]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89       242
#            1       0.89      0.92      0.90       258
#
#     accuracy                           0.90       500
#    macro avg       0.90      0.90      0.90       500
# weighted avg       0.90      0.90      0.90       500

# %%
DTA=accuracy_score(y_test,dtpred)
DTcv=cross_val_score(dtcv,xtrain,ytrain,cv=9).mean()
print("The cv score is: ", DTcv,"\nThe accuracy score is: ", DTA)
# Out:
# The cv score is:  0.8931901410279719
# The accuracy score is:  0.898

# %%
svcv=SVC()
svcv.fit(x_train, y_train)
svcv.score(x_train,y_train)
svpred=svcv.predict(x_test)

print (accuracy_score(y_test,svpred))
print (confusion_matrix(y_test,svpred))
print (classification_report(y_test,svpred))
print('\n')
# Out:
# 0.906
# [[212  30]
#  [ 17 241]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       242
#            1       0.89      0.93      0.91       258
#
#     accuracy                           0.91       500
#    macro avg       0.91      0.91      0.91       500
# weighted avg       0.91      0.91      0.91       500

# %%
SVA=accuracy_score(y_test,svpred)
SVcv=cross_val_score(svcv,xtrain,ytrain,cv=9).mean()
print("The cv score is: ", SVcv,"\nThe accuracy score is: ", SVA)
# Out:
# The cv score is:  0.8871978229690617
# The accuracy score is:  0.906

# %% [markdown]
# RandomForestClassifier(), have lesser diffrence in cv and accuracy score.
# The cv score is:  0.9423998707171448
# The accuracy score is:  0.954

# %%
Model= [LogisticRegression(),RandomForestClassifier(),GaussianNB(),KNeighborsClassifier(),DecisionTreeClassifier(), SVC()]

for m in Model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print('Accuracy score of', m, 'is:')
    print (accuracy_score(y_test,predm))
    print (confusion_matrix(y_test,predm))
    print (classification_report(y_test,predm))
    print('\n')
# Out:
# Accuracy score of LogisticRegression() is:
# 0.85
# [[198  44]
#  [ 31 227]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84       242
#            1       0.84      0.88      0.86       258
#
#     accuracy                           0.85       500
#    macro avg       0.85      0.85      0.85       500
# weighted avg       0.85      0.85      0.85       500
#
#
#
# Accuracy score of RandomForestClassifier() is:
# 0.948
# [[230  12]
#  [ 14 244]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95       242
#            1       0.95      0.95      0.95       258
#
#     accuracy                           0.95       500
#    macro avg       0.95      0.95      0.95       500
# weighted avg       0.95      0.95      0.95       500
#
#
#
# Accuracy score of GaussianNB() is:
# 0.828
# [[196  46]
#  [ 40 218]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82       242
#            1       0.83      0.84      0.84       258
#
#     accuracy                           0.83       500
#    macro avg       0.83      0.83      0.83       500
# weighted avg       0.83      0.83      0.83       500
#
#
#
# Accuracy score of KNeighborsClassifier() is:
# 0.878
# [[188  54]
#  [  7 251]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.78      0.86       242
#            1       0.82      0.97      0.89       258
#
#     accuracy                           0.88       500
#    macro avg       0.89      0.87      0.88       500
# weighted avg       0.89      0.88      0.88       500
#
#
#
# Accuracy score of DecisionTreeClassifier() is:
# 0.892
# [[206  36]
#  [ 18 240]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88       242
#            1       0.87      0.93      0.90       258
#
#     accuracy                           0.89       500
#    macro avg       0.89      0.89      0.89       500
# weighted avg       0.89      0.89      0.89       500
#
#
#
# Accuracy score of SVC() is:
# 0.906
# [[212  30]
#  [ 17 241]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       242
#            1       0.89      0.93      0.91       258
#
#     accuracy                           0.91       500
#    macro avg       0.91      0.91      0.91       500
# weighted avg       0.91      0.91      0.91       500

# %% [markdown]
# # Now check accuracy usig Hyperparameter tuning: GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters= {'n_estimators' : [20, 40, 60, 80, 100,120, 140,160, 200], 'criterion':['gini', 'entropy'], 'bootstrap':[0,1,0,1,0,1]}
model=RandomForestClassifier()
Grid= GridSearchCV(estimator=model, param_grid= parameters)
Grid.fit(x_train, y_train)


print(Grid)
print(Grid.best_score_)

print(Grid.best_params_)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [0, 1, 0, 1, 0, 1],
#                          'criterion': ['gini', 'entropy'],
#                          'n_estimators': [20, 40, 60, 80, 100, 120, 140, 160,
#                                           200]})
# 0.9549999999999998
# {'bootstrap': 0, 'criterion': 'entropy', 'n_estimators': 100}

# %%
p=Grid.predict(x_test)

print (accuracy_score(y_test,p))
print (confusion_matrix(y_test,p))
print (classification_report(y_test,p))
print('\n')
# Out:
# 0.96
# [[235   7]
#  [ 13 245]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       242
#            1       0.97      0.95      0.96       258
#
#     accuracy                           0.96       500
#    macro avg       0.96      0.96      0.96       500
# weighted avg       0.96      0.96      0.96       500

# %%
RF=RandomForestClassifier()
RF.fit(x_train,y_train)
RF.score(x_train,y_train)

RFpred=RF.predict(x_test)
print(accuracy_score(y_test,RFpred ))
print(confusion_matrix(y_test,RFpred ))
print(classification_report(y_test,RFpred ))
# Out:
# 0.95
# [[229  13]
#  [ 12 246]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       242
#            1       0.95      0.95      0.95       258
#
#     accuracy                           0.95       500
#    macro avg       0.95      0.95      0.95       500
# weighted avg       0.95      0.95      0.95       500

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds= roc_curve(p, y_test)
roc_auc= auc(fpr, tpr)

plt.figure()
plt.plot(fpr,tpr, color='darkorange', lw=10,label='ROC curve (area= %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color ='navy', lw=10, linestyle= '--')
plt.xlim([0.0, 1.0])
plt.xlim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Now Saving Best Model.

# %%
import pickle
filename='Red_Wine_Quality_Prediction.pkl'
pickle.dump(RF,open(filename,'wb'))
